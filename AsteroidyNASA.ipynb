# %% [markdown]
# <a href="https://colab.research.google.com/github/domi-n/NASA_Asteroid_Classification/blob/main/AsteroidyNASA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
 
# to get the id part of the file
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('xclara.csv') 
 
df = pd.read_csv('xclara.csv')
print(df)

# %%
link = 'https://drive.google.com/file/d/1XYcG1VYqR2YkBJK0aQ4YYjv7H7ZT3r6l/view?usp=share_link'

# %%
df
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="zWc49ApO53GMaioVTdNx6w">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>nasa.csv - Google 雲端硬碟</title><meta property="og:title" content="nasa.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1XYcG1VYqR2YkBJK0aQ4YYjv7H7ZT3r6l/view?usp=share_link&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                                 try{
# 1                                                   /*
# 2               Copyright The Closure Library Authors.
# 3                  SPDX-License-Identifier: Apache-2.0
# 4                                                   */
# ..                                                 ...
# 112                                  var ck=function(a
# 113                     }catch(e){_._DumpException(e)}
# 114                                    })(this.gbar_);
# 115                                     // Google Inc.
# 116  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 112                                                  b  c){_.se.log(46
# 113                                                NaN             NaN
# 114                                                NaN             NaN
# 115                                                NaN             NaN
# 116  wb" nonce="sjI3sweC6p-iAhZTplvWIA"></script></...             NaN
#
#     700" nonce="zWc49ApO53GMaioVTdNx6w"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.tdLy7WXfKaU.L.X.O/am=ABA/d=0/rs=AO0039tni7DjYNo6AIS8TA95G9P3JL0oFg" nonce="zWc49ApO53GMaioVTdNx6w"><script nonce="sjI3sweC6p-iAhZTplvWIA">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                             {att:a
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"      docs-fl:1 docs-l1lc:5  \
# 0                    NaN                     NaN            NaN         NaN
# 1                    NaN                     NaN            NaN         NaN
# 2                    NaN                     NaN            NaN         NaN
# 3                    NaN                     NaN            NaN         NaN
# 4                    NaN                     NaN            NaN         NaN
# ..                   ...                     ...            ...         ...
# 112                max:b                url:c})}  ek=function(a           b
# 113                  NaN                     NaN            NaN         NaN
# 114                  NaN                     NaN            NaN         NaN
# 115                  NaN                     NaN            NaN         NaN
# 116                  NaN                     NaN            NaN         NaN
#
#     docs-l1lm:"TPE" docs-l2lc:5  ... 0.82 0.83 0.84 0.85 1].12 [[null.2  \
# 0               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# ..              ...         ...  ...  ...  ...  ...  ...   ...      ...
# 112  c){_.se.log(47      {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 113             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 114             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 115             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 116             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.203 null.204  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 112      NaN      NaN
# 113      NaN      NaN
# 114      NaN      NaN
# 115      NaN      NaN
# 116      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.r9z7JAX0qJ8.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTsiuldpsg19V7yjpkhJnRkdrsvlFQ]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
# [117 rows x 799 columns]
